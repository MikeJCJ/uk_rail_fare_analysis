# %%
import sqlite3
import pathlib
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Locating files
current_file_path = pathlib.Path().resolve()
base_folder = current_file_path.parents[0]
database_path = base_folder.joinpath('2. Data\\Database\\nrdp_fare_data.db')
# Out:
# Current path: C:\Users\mikey\OneDrive\OLD\Documents\Coding projects\Rail Analysis Project

# %%
# reading database table into a dataframe
db_conn = sqlite3.connect(database_path)
df = pd.read_sql_query('SELECT * FROM fare_data_cleaned', db_conn)
db_conn.close()

# %%
# Forming graph
G = nx.Graph()
G.add_node(1)
G.add_node(3)

# %%
#Displaying graph
G = nx.petersen_graph()
subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
subax2 = plt.subplot(122)
nx.draw_shell(G, nlist=[range(5, 10), range(5)], with_labels=True, font_weight='bold')
